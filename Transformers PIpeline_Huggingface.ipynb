# %%
import os
import warnings

os.environ["HF_HUB_DISABLE_SYMLINKS_WARNING"] = "1"
warnings.filterwarnings('ignore')

# %%
from transformers import pipeline

classifier = pipeline("sentiment-analysis")
classifier("I've been waiting for a HuggingFace course my whole life.")
# Out:
# [transformers] No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# [{'label': 'POSITIVE', 'score': 0.9598049521446228}]

# %% [markdown]
# # Zero-shot classification

# %%
classifier = pipeline("zero-shot-classification")
classifier(
    "This is a course about the Transformers library",
    candidate_labels=["education", "politics", "business"],
)
# Out:
# [transformers] No model was supplied, defaulted to facebook/bart-large-mnli and revision d7645e1.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/515 [00:00<?, ?it/s]
# {'sequence': 'This is a course about the Transformers library',
#  'labels': ['education', 'business', 'politics'],
#  'scores': [0.8445990681648254, 0.11197425425052643, 0.04342665150761604]}

# %% [markdown]
# # Text Generation

# %%
generator = pipeline("text-generation")
generator("In this course, we will teach you how to")
# Out:
# [transformers] No model was supplied, defaulted to HuggingFaceTB/SmolLM3-3B and revision a07cc9a.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/326 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/182 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/289 [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': "In this course, we will teach you how to create simple and complex digital products from scratch. We will cover a wide range of topics, from the fundamentals of graphic design to the latest trends in UX/UI design. Our instructors are industry experts who have worked on some of the most successful projects in the world. You will learn how to use industry-standard software and tools, such as Adobe Creative Suite and Sketch. You will also learn about design principles, user experience, and user interface design. Whether you are a beginner or an experienced designer, this course will give you the skills and knowledge you need to create stunning digital products. We are committed to providing an engaging and interactive learning experience, with plenty of opportunities for hands-on practice and feedback from our instructors. By the end of this course, you will be able to create your own digital products, whether it's a website, an app, or a product design. Let's get started!\nWe will cover a wide range of topics, including:\n- Introduction to graphic design and UX/UI design\n- Fundamentals of design principles\n- Color theory and typography\n- User experience and user interface design\n- Adobe Creative Suite and Sketch\n- Digital product development process\n- Design trends and best practices\n- Case studies and projects\n- Feedback and critique\n- Industry standards and guidelines"}]

# %%
generator = pipeline("text-generation", model="HuggingFaceTB/SmolLM2-360M")
generator(
    "In this course, we will teach you how to",
    max_length=30,
    num_return_sequences=2,
)
# Out:
# config.json:   0%|          | 0.00/689 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/724M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/290 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/831 [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# [transformers] Passing `generation_config` together with generation-related arguments=({'max_length', 'num_return_sequences'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'In this course, we will teach you how to make your own custom games for the iPhone, iPad, and iPod touch.\n\nOur courses start at a basic level. You won’t need a lot of programming experience or knowledge of any scripting languages to get started. We will teach you the fundamentals of programming and scripting and how to use the many different iPhone devices to create games. We will teach you how to make the most of the unique features of the iPhone and iPad.\n\nYou’ll learn how to use the various iPhone and iPad devices to make games that can be played on your own or with friends. We will show you how to make games for the iPhone, iPad, iPod touch, and the Apple Watch.\n\nWe will also teach you how to make games that can be downloaded to your iPod, iPad, iPhone, and iPod touch. It’s a great way to get started with the iPhone.\n\nMost of the lessons in this course are designed to be self-paced and can be completed on your own time. Many of the lessons are designed to be completed in a short amount of time.\n\nIn this course, you will learn how to use the iPhone and iPad to create games. You won’t need any programming experience or knowledge of any programming languages to get started'},
#  {'generated_text': "In this course, we will teach you how to create your own music and share it with others. We will start by learning how to play simple tunes using objects like household items or household sounds. Then, we will move on to more complex compositions, exploring different instruments and techniques.\n\nFor example, imagine you want to compose a song about your favorite animal. You might choose a specific tune, play a simple instrument, and then add vocals to bring your song to life. This is just one example of what you can do with music!\n\nThroughout this course, we will also learn about the importance of listening and appreciating music. We will explore different genres and styles, and even try our hand at creating our own music. Who knows – maybe you'll become the next big pop star!\n\nBut don't worry – we won't just teach you how to write music. We'll also give you tips and tricks for making your music stand out and making it more enjoyable for others to listen to. For example, you might learn how to use special effects or techniques to make your music sound more dramatic or exciting.\n\nBy the end of this course, you will have all the skills and resources you need to create your own music and share it with the world. So let's get started!"}]

# %% [markdown]
# # Mask filling

# %%
unmasker = pipeline("fill-mask")
unmasker("This course will teach you all about <mask> models.", top_k=2)
# Out:
# [transformers] No model was supplied, defaulted to distilbert/distilroberta-base and revision fb53ab8.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/331M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/106 [00:00<?, ?it/s]
# [transformers] RobertaForMaskedLM LOAD REPORT from: distilbert/distilroberta-base
# Key                         | Status     |  |
# ----------------------------+------------+--+-
# roberta.pooler.dense.weight | UNEXPECTED |  |
# roberta.pooler.dense.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# [{'score': 0.1961967945098877,
#   'token': 30412,
#   'token_str': ' mathematical',
#   'sequence': 'This course will teach you all about mathematical models.'},
#  {'score': 0.04052725061774254,
#   'token': 38163,
#   'token_str': ' computational',
#   'sequence': 'This course will teach you all about computational models.'}]

# %%
from transformers import pipeline

unmasker = pipeline("fill-mask", model="bert-base-uncased")
result = unmasker("This man works as a [MASK].")
print([r["token_str"] for r in result])

result = unmasker("This woman works as a [MASK].")
print([r["token_str"] for r in result])
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/202 [00:00<?, ?it/s]
# [transformers] BertForMaskedLM LOAD REPORT from: bert-base-uncased
# Key                         | Status     |  |
# ----------------------------+------------+--+-
# cls.seq_relationship.weight | UNEXPECTED |  |
# bert.pooler.dense.weight    | UNEXPECTED |  |
# cls.seq_relationship.bias   | UNEXPECTED |  |
# bert.pooler.dense.bias      | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# ['carpenter', 'lawyer', 'farmer', 'businessman', 'doctor']
# ['nurse', 'maid', 'teacher', 'waitress', 'prostitute']
