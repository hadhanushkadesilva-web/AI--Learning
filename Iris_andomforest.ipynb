# %%
# !pip install scikit-learn pandas numpy

# Loading the library with the iris dataset
from sklearn.datasets import load_iris

# Loading scikit's random forest classifier library
from sklearn.ensemble import RandomForestClassifier

# Loading pandas
import pandas as pd

# Loading numpy
import numpy as np

# Setting random seed
np.random.seed(0)
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: scikit-learn in c:\users\desil_z3d\desktop\studies\jupyterproject1\.venv\lib\site-packages (1.8.0)
# Requirement already satisfied: pandas in c:\users\desil_z3d\desktop\studies\jupyterproject1\.venv\lib\site-packages (3.0.2)
# Requirement already satisfied: numpy in c:\users\desil_z3d\desktop\studies\jupyterproject1\.venv\lib\site-packages (2.4.4)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\desil_z3d\desktop\studies\jupyterproject1\.venv\lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\desil_z3d\desktop\studies\jupyterproject1\.venv\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\desil_z3d\desktop\studies\jupyterproject1\.venv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\desil_z3d\desktop\studies\jupyterproject1\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\desil_z3d\desktop\studies\jupyterproject1\.venv\lib\site-packages (from pandas) (2026.1)
# Requirement already satisfied: six>=1.5 in c:\users\desil_z3d\desktop\studies\jupyterproject1\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
